# %%
! pip install -Uq pandas requests yfinance

# %%
import yfinance as yf
import pandas as pd


class tdf_lookup(yf.Lookup):

# %%
spy = yf.Ticker('RELIANCE.NS')
spy.quarterly_income_stmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         1.553159e+10
# Tax Rate For Calcs                                  1.740430e-01
# Normalized EBITDA                                   3.525800e+11
# Total Unusual Items                                 8.924000e+10
# Total Unusual Items Excluding Goodwill              8.924000e+10
# Net Income From Continuing Operation Net Minori...  2.699400e+11
# Reconciled Cost Of Revenue                          1.664920e+12
# EBITDA                                              4.418200e+11
# EBIT                                                4.418200e+11
# Net Interest Income                                -7.036000e+10
# Interest Expense                                    7.036000e+10
# Normalized Income                                   1.962316e+11
# Net Income From Continuing And Discontinued Ope...  2.699400e+11
# ...

# %%
# ticker list
ticker_list = yf.Lookup(query="index")
ticker_list.get_mutualfund()
# Out:
#        exchange   quoteType   rank  regularMarketChange  \
# symbol
# INDEX       NAS  mutualfund  20001                 0.39
# FXAIX       NAS  mutualfund  20242                 1.57
# VFIAX       NAS  mutualfund  20234                 4.16
# VFINX       NAS  mutualfund  20141                 4.16
# VIGAX       NAS  mutualfund  20057                 1.49
# VINIX       NAS  mutualfund  20057                 3.63
# SWPPX       NAS  mutualfund  20040                 0.11
# FZROX       NAS  mutualfund  20030                 0.16
# PREIX       NAS  mutualfund  20030                 1.16
# FSKAX       NAS  mutualfund  20030                 1.24
# VBIAX       NAS  mutualfund  20030                 0.25
# VBTLX       NAS  mutualfund  20029                 0.02
# VTIAX       NAS  mutualfund  20028                 0.31
# VBINX       NAS  mutualfund  20024                 0.25
# FSPGX       NAS  mutualfund  20024                 0.30
# VHYAX       NAS  mutualfund  20023                 0.27
# ...

# %%
https://query1.finance.yahoo.com/v1/finance/lookup
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for i in list(ticker_list):
#       2     print(i)
#
# TypeError: 'Lookup' object is not iterable

# %% [markdown]
# 1. https://support.zerodha.com/category/your-zerodha-account/transfer-of-shares-and-conversion-of-shares/cdsl-easi-easiest/articles/what-is-cdsl-easi-and-how-do-i-register
