# %% [markdown]
# #### Ref:
#
# 1. mftool(pypi package): https://pypi.org/project/mftool/2.9/
# 2. https://www.geeksforgeeks.org/python/how-to-get-real-time-mutual-funds-information-using-python/

# %%
# ! pip uninstall -y mftool

# %%
! pip install -q mftool==2.9
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from mftool import Mftool
import pandas as pd
import json
import datetime


mf_obj = Mftool()

schemes_dict = mf_obj.get_scheme_codes()

# %%
# get all  mutual fund schemes
scheme_codes = []
scheme_names = []
scheme_aum = []
for i, (key, value) in enumerate(schemes_dict.items()):
    if i == 0:
        continue
    scheme_codes.append(key)
    scheme_names.append(value)
    scheme_aum.append(value.split('-')[0])
schemes_df = pd.DataFrame({"Scheme Code": scheme_codes, 
                           "Scheme Name": scheme_names, 
                           "Scheme AUM": scheme_aum})

# %%
trending = "https://www.amfiindia.com/api/search/trending"
investment_schemes = "https://www.amfiindia.com/api/investmentscheme?MF_ID=53&quarterName=01-oct-2025"
debt_group_companies_list = "https://www.amfiindia.com/api/list-of-all-group-companies?page=1&pageSize=10"

# "https://www.amfiindia.com/otherdata/fund-performance"
# post
"https://www.amfiindia.com/gateway/pollingsebi/api/amfi/fundperformance"
category
: 
1
maturityType
: 
1
mfid
: 
0
reportDate
: 
"26-Feb-2026"
subCategory
: 
1

# %%
schemes_dict
# Out:
# {'Scheme Code': 'Scheme Name',
#  '119551': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - IDCW',
#  '119552': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - MONTHLY IDCW',
#  '119553': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - Direct - Quarterly IDCW',
#  '108272': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - REGULAR - IDCW',
#  '110282': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - REGULAR - MONTHLY IDCW',
#  '108274': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - REGULAR - Quarterly IDCW',
#  '110490': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - retail - monthly IDCW',
#  '106157': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - retail - quarterly IDCW',
#  '108273': 'Aditya Birla Sun Life Banking & PSU Debt Fund - Regular Plan-Growth',
#  '103176': 'Aditya Birla Sun Life Banking & PSU Debt Fund - Retail Plan-Growth',
#  '119550': 'Aditya Birla Sun Life Banking & PSU Debt Fund- Direct Plan-Growth',
# ...

# %%
aums_list = schemes_df['Scheme AUM'].unique()

# %%
aums_list
# Out:
# array(['Aditya Birla Sun Life Banking & PSU Debt Fund  ',
#        'Aditya Birla Sun Life Banking & PSU Debt Fund ',
#        'Aditya Birla Sun Life Banking & PSU Debt Fund', ...,
#        'UTI Fixed Term Income Fund ',
#        'UTI Fixed Term Income Fund Series XXXVI ',
#        'UTI Quarterly Interval Fund '], shape=(3372,), dtype=object)

# %%
mf_obj.get_scheme_details(119551)
# Out:
# {'fund_house': 'Aditya Birla Sun Life Mutual Fund',
#  'scheme_type': 'Open Ended Schemes',
#  'scheme_category': 'Debt Scheme - Banking and PSU Fund',
#  'scheme_code': 119551,
#  'scheme_name': 'Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - IDCW',
#  'scheme_start_date': {'date': '02-01-2013', 'nav': '103.00590'}}

# %%
mf_obj.get_all_amc_profiles()
# Out:
# '[{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]'

# %%
mf_obj.get_open_ended_equity_scheme_performance()
# Out:
# {'Large Cap': [],
#  'Large & Mid Cap': [],
#  'Multi Cap': [],
#  'Mid Cap': [],
#  'Small Cap': [],
#  'Value': [],
#  'ELSS': [],
#  'Contra': [],
#  'Dividend Yield': [],
#  'Focused': []}

# %%
mf_obj.get_all_amc_profiles

# %%
mf_obj.get_available_schemes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 obj.get_available_schemes()
#
# TypeError: Mftool.get_available_schemes() missing 1 required positional argument: 'amc_name'

# %%
import requests
import pandas as pd

amfi_base_url = "https://www.amfiindia.com/gateway/pollingsebi/api/"
amfi_headers = {
    "Content-Type": "application/json",
    "Accept": "application/json, text/plain, */*",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
    "Origin": "https://www.amfiindia.com",
    "Referer": "https://www.amfiindia.com/"
}

def get_amfi_fund_performance():
    full_url = amfi_base_url + "amfi/fundperformance"
    payload = {
        "maturityType":1,
        "category":1,
        "subCategory":1,
        "mfid":0,
        "reportDate":"27-Mar-2026"
    }
    try:
        response = requests.post(url=full_url, 
                                headers=amfi_headers, 
                                json=payload)
        response.raise_for_status()
        data = response.json()
        df = pd.DataFrame(data.get("data"))
        return df
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return False

# %%
print(get_amfi_fund_performance())
# Out:
#      preNavDate  preNavRegular  preNavDirect specialCharAum  \
# 0   25-Mar-2026       486.6200      540.2000           None
# 1   25-Mar-2026        56.2600       65.1000           None
# 2   25-Mar-2026         9.5400        9.7700           None
# 3   25-Mar-2026        72.5820       84.0250           None
# 4   25-Mar-2026        15.4300       16.4000           None
# 5   25-Mar-2026       207.3372      241.1058           None
# 6   25-Mar-2026        58.1900       67.7700           None
# 7   25-Mar-2026       438.4920      482.4080           None
# 8   25-Mar-2026        79.0400       91.6700           None
# 9   25-Mar-2026       964.0598     1072.6925           None
# 10  25-Mar-2026        40.4800       48.9800           None
# 11  25-Mar-2026      1066.2650     1157.9790           None
# 12  25-Mar-2026       452.2721      505.2014           None
# 13  25-Mar-2026       103.9300      114.5600           None
# 14  25-Mar-2026        16.0662       17.8669           None
# ...

# %%
# Out:
# 200

# %%
response.json()
# Out:
# {'validationStatus': 'SUCCESS',
#  'validationMsg': 'SUCCESS',
#  'errorMsgs': [],
#  'data': [{'preNavDate': '25-Mar-2026',
#    'preNavRegular': 486.62,
#    'preNavDirect': 540.2,
#    'specialCharAum': None,
#    'schemeName': 'Aditya Birla Sun Life Large Cap Fund',
#    'benchmark': 'Nifty 100 TRI',
#    'riskometerScheme': 'Very High',
#    'riskometerBenchmark': 'Very High',
#    'navDate': '27-Mar-2026',
#    'navRegular': 476.79,
#    'navDirect': 529.31,
#    'return7DaysRegular': None,
#    'return7DaysDirect': None,
#    'return7DaysBenchmark': None,
#    'return15DaysRegular': None,
#    'return15DaysDirect': None,
#    'return15DaysBenchmark': None,
#    'return1MonthRegular': None,
#    'return1MonthDirect': None,
#    'return1MonthBenchmark': None,
#    'return3MonthRegular': None,
#    'return3MonthDirect': None,
#    'return3MonthBenchmark': None,
#    'return6MonthRegular': None,
#    'return6MonthDirect': None,
#    'return6MonthBenchmark': None,
# ...
